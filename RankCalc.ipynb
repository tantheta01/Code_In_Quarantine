# %%
import pandas as pd
import numpy as np
import requests
import bs4
import html5lib
import csv

# %%
res = requests.get('https://github.com/ritik02mandal/CodeInQuarantine/blob/master/Week_1_Python/marksheet.csv')
# print(res.content)
soup = bs4.BeautifulSoup(res.content, 'html5lib')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#     <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#
#
#
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-146fab5ea30e8afac08dd11013bb4ee0.css" integrity="sha512-FG+rXqMOivrAjdEQE7tO4BwM1poGmg70hJFTlNSxjX87grtrZ6UnPR8NkzwUHlQEGviu9XuRYeO8zH9YwvZhdg==" media="all" rel="stylesheet"/>
# ...

# %%
table = soup.find('div', attrs = {'class' : 'markdown-body'})
print(table)
# Out:
# <div class="markdown-body">
#     <table class="js-csv-data csv-data js-file-line-container">
#       <thead>
#         <tr class="js-file-line" id="LC1">
#           <td class="blob-num js-line-number" data-line-number="1" id="L1"></td>
#             <th>1</th>
#             <th>76</th>
#         </tr>
#       </thead>
#       <tbody>
#           <tr class="js-file-line" id="LC2">
#             <td class="blob-num js-line-number" data-line-number="2" id="L2"></td>
#               <td>2</td>
#               <td>99.5</td>
#           </tr>
#           <tr class="js-file-line" id="LC3">
#             <td class="blob-num js-line-number" data-line-number="3" id="L3"></td>
#               <td>3</td>
#               <td>66.5</td>
#           </tr>
#           <tr class="js-file-line" id="LC4">
#             <td class="blob-num js-line-number" data-line-number="4" id="L4"></td>
#               <td>4</td>
#               <td>91.5</td>
#           </tr>
# ...

# %%
df = pd.DataFrame(columns = ['index', 'marks'])

# %%
fentry = []
for row in table.findAll('th'):
    fentry.append(int(row.text))
    
print(fentry)
df.loc[0] = fentry
# Out:
# [1, 76]

# %%
tbody = table.find('tbody')
print(tbody)
# Out:
# <tbody>
#           <tr class="js-file-line" id="LC2">
#             <td class="blob-num js-line-number" data-line-number="2" id="L2"></td>
#               <td>2</td>
#               <td>99.5</td>
#           </tr>
#           <tr class="js-file-line" id="LC3">
#             <td class="blob-num js-line-number" data-line-number="3" id="L3"></td>
#               <td>3</td>
#               <td>66.5</td>
#           </tr>
#           <tr class="js-file-line" id="LC4">
#             <td class="blob-num js-line-number" data-line-number="4" id="L4"></td>
#               <td>4</td>
#               <td>91.5</td>
#           </tr>
#           <tr class="js-file-line" id="LC5">
#             <td class="blob-num js-line-number" data-line-number="5" id="L5"></td>
#               <td>5</td>
#               <td>1.5</td>
#           </tr>
#           <tr class="js-file-line" id="LC6">
#             <td class="blob-num js-line-number" data-line-number="6" id="L6"></td>
#               <td>6</td>
# ...

# %%
for row in tbody.findAll('tr'):
    fentry = []
#     i = 0
    for entry in row.findAll('td'):
       print(entry.text)            
#     df.loc[len(df)] = fentry
# Out:
# 2
# 99.5
#
# 3
# 66.5
#
# 4
# 91.5
#
# 5
# 1.5
#
# 6
# 37.5
#
# 7
# 23.5
#
# 8
# 90.5
#
# 9
# 18
#
# 10
# 13.5
#
# 11
# 72
#
# 12
# 94.5
#
# 13
# 74
#
# 14
# 29
#
# 15
# 9
#
# 16
# 29
#
# 17
# 19.5
#
# 18
# 55
#
# 19
# 80.5
#
# 20
# 68.5
#
# 21
# 47
#
# 22
# 19
#
# 23
# 33
#
# 24
# 6.5
#
# 25
# 89
#
# 26
# 52.5
#
# 27
# 71
#
# 28
# 89.5
#
# 29
# 62
#
# 30
# 40.5
#
# 31
# 89.5
#
# 32
# 48.5
#
# 33
# 40
#
# 34
# 18
#
# 35
# 30
#
# 36
# 78.5
#
# 37
# 18.5
#
# 38
# 5
#
# 39
# 46
#
# 40
# 2
#
# 41
# 65.5
#
# 42
# 76.5
#
# 43
# 6
#
# 44
# 88.5
#
# 45
# 5
#
# 46
# 12
#
# 47
# 52
#
# 48
# 10.5
#
# 49
# 47.5
#
# 50
# 65.5
#
# 51
# 96.5
#
# 52
# 85.5
#
# 53
# 85.5
#
# 54
# 57.5
#
# 55
# 25.5
#
# 56
# 6.5
#
# 57
# 24.5
#
# 58
# 68.5
#
# 59
# 31.5
#
# 60
# 71
#
# 61
# 77
#
# 62
# 97.5
#
# 63
# 28.5
#
# 64
# 72.5
#
# 65
# 95.5
#
# 66
# 19.5
#
# 67
# 73
#
# 68
# 93
#
# 69
# 77
#
# 70
# 20.5
#
# 71
# 24
#
# 72
# 21
#
# 73
# 86.5
#
# 74
# 45.5
#
# 75
# 20
#
# 76
# 96.5
#
# 77
# 84.5
#
# 78
# 58
#
# ...

# %%
g = tbody.find('\n')
print(g)
# Out:
# None

# %%
print(df)
# Out:
#   index marks
# 0     1    76

# %%
df = pd.read_csv('datafile.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      1000 non-null   int64
#  1    Marks  1000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 15.8 KB
